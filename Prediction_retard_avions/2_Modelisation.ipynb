# %%
# %matplotlib inline

from timeit import default_timer as timer
from collections import defaultdict
import itertools
import pickle

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, GradientBoostingRegressor

X = pd.read_csv(f'C:/Users/Serphone/Data/OCR_DS_P4/AIRLINE_DATASETS/VX.csv')
y = X.pop('ARR_DELAY')

# %% [markdown]
# ## Feature engineering

# %%
def label_encoding(tr, ts, target_tr, cols):
    for col in cols:
        le = LabelEncoder().fit(X[f'{col}'])
        
        tr[f'{col}'] = le.transform(tr[f'{col}'])
        ts[f'{col}'] = le.transform(ts[f'{col}'])
    
    return tr, ts

# %%
def count_encoding(tr, ts, target_tr, cols):
    for col in cols:
        # Count calculated only on train set
        counts = tr.groupby(by=f'{col}')[f'{col}'].count()

        tr[f'{col}'] = tr[f'{col}'].map(counts)
        ts[f'{col}'] = ts[f'{col}'].map(counts)
        ts[f'{col}'].fillna(counts.mean(), inplace=True)
        
    return tr, ts

# %%
def one_hot_encoding(tr, ts, target_tr, cols):
    tr, ts = label_encoding(tr, ts, target_tr, cols)
    
    ohe = OneHotEncoder(categorical_features=[_ in cols for _ in X.columns]).fit(pd.concat([tr, ts], axis=0))
    
    tr = ohe.transform(tr)
    ts = ohe.transform(ts)

    return tr, ts

# %%
def circular_encoding(tr, ts, target_tr, cols):
    tr, ts = label_encoding(tr, ts, target_tr, cols)
    
    for col in cols:
        nb_labels = X.nunique()[f'{col}']
        trig_dict = {f'{col}_1': np.cos([2*np.pi*x/nb_labels for x in range(nb_labels)]),
                     f'{col}_2': np.sin([2*np.pi*x/nb_labels for x in range(nb_labels)])}
        encondigs = pd.DataFrame(trig_dict, index=np.arange(nb_labels))

        tr[f'{col}_1'] = tr[f'{col}'].map(encondigs[f'{col}_1'])
        tr[f'{col}_2'] = tr[f'{col}'].map(encondigs[f'{col}_2'])
        tr.drop([f'{col}'], axis=1, inplace=True)

        ts[f'{col}_1'] = ts[f'{col}'].map(encondigs[f'{col}_1'])    
        ts[f'{col}_2'] = ts[f'{col}'].map(encondigs[f'{col}_2'])
        ts.drop([f'{col}'], axis=1, inplace=True)
        
    return tr, ts

# %%
def target_encoding(tr, ts, target_tr, cols):
    for col in cols:
        # Means calculated only on train set
        means = pd.concat([tr, target_tr], axis=1).groupby(by=f'{col}').ARR_DELAY.mean()

        tr[f'{col}'] = tr[f'{col}'].map(means)
        ts[f'{col}'] = ts[f'{col}'].map(means)
        ts[f'{col}'].fillna(target_tr.mean(), inplace=True)
    
    return tr, ts

# %% [markdown]
# ## Helper functions

# %%
def initialize_data(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=16)

    X_train.is_copy = None
    X_test.is_copy = None
    y_train.is_copy = None
    y_test.is_copy = None
    
    return X_train, X_test, y_train, y_test

# %%
def get_scores(y_true, y_pred, verbose=1):
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    if verbose > 0:
        print(f'MSE: {mse:.2f}, RMSE: {mse ** 0.5:.2f} mn')
        print(f'MAE: {mae:.2f} mn')
        print(f'R2: {r2*100:.2f} %')
    return mse, mae, r2

# %%
def standardize(X_train, X_test):
    scaler = StandardScaler(with_mean=False).fit(X_train)
    X_train_std = scaler.transform(X_train)
    X_test_std = scaler.transform(X_test)
    
    return X_train_std, X_test_std

# %%
def cross_validation(model, params, X_train, y_train, n_folds=5, verbose=1):
    keys, values = zip(*params.items())
    params_list = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    if verbose > 0:
        print(f"--- {model.__name__} CV ---")
        print(f"Testing: {params}")
        print(f"Fitting {n_folds} folds for each of {len(params_list)} candidates,", 
              f"totalling {n_folds * len(params_list)} fits")
    folds = KFold(n_splits=n_folds)
    scores = []
    cv_results = {'mean_test_score': []}
    
    
    for param_set in params_list:
        scores.append([])
        if model.__name__ not in ['Ridge', 'Lasso', 'ElasticNet', 'GradientBoostingRegressor']:
            param_set['n_jobs'] = -1
        start = timer()
        for train_idx, test_idx in folds.split(X_train, y_train):
            model_cv = model(**param_set).fit(X_train[train_idx],
                                                         y_train.iloc[train_idx])
            scores[-1].append(model_cv.score(X_train[test_idx], 
                                             y_train.iloc[test_idx]))
        cv_results['mean_test_score'].append(np.mean(scores[-1]))
        end = timer()
        if verbose > 1:
            print(f"{param_set} - Score: {cv_results['mean_test_score'][-1]:.4f} - Time: {end-start:.2f}s")
        
    return params_list[np.argmax(cv_results['mean_test_score'])]

# %%
def test_model(X_tr, X_ts, y_tr, y_ts, model, params={}, with_cv=False, n_folds=5, params_cv={}, 
               standardize_data=True, poly_features_degree=1, verbose=1):
    
    if standardize_data:
        X_train_std, X_test_std = standardize(X_tr, X_ts)
        tr, ts = X_train_std, X_test_std
    else:
        tr, ts = X_tr.copy(), X_tr.copy()

    if poly_features_degree > 1:
        poly_text = " with polynomial features"
        poly = PolynomialFeatures(poly_features_degree)
        tr = poly.fit_transform(tr)
        ts = poly.transform(ts)
    else:
        poly_text = ""
    
    if with_cv:
        best_params = cross_validation(model, params_cv, tr, y_tr, n_folds=n_folds, verbose=verbose)
    else:
        best_params = params
        
    if model.__name__ not in ['Ridge', 'Lasso', 'ElasticNet', 'GradientBoostingRegressor']:
        best_params['n_jobs'] = -1
    
    if verbose > 0:
        print(f"--- {model.__name__}{poly_text} ({best_params}) ---")
        
    start = timer()
    reg = model(**best_params).fit(tr, y_tr)
    fit_time = timer() - start
    y_pred = reg.predict(ts)
    pred_time = timer() - start - fit_time
    
    mse, mae, r2 = get_scores(y_ts, y_pred, verbose=verbose)
    if verbose > 0:
        print(f"Fit time: {fit_time:.2f}s")
        print(f"Pred time: {pred_time:.2f}s")
    
    return {'MSE': f'{mse:.2f}', 'RMSE (mn)': f'{mse**0.5:.2f}', 
            'MAE (mn)': f'{mae:.2f}', 'R2 (%)': f'{r2*100:.2f}', 
            'fit_time (s)': f'{fit_time:.2f}', 'pred_time (s)': f'{pred_time:.2f}', 
            'total_time (s)': f'{fit_time + pred_time:.2f}',}

# %% [markdown]
# ## Encodings

# %%
encodings = {
    'label': label_encoding,
    'count': count_encoding,
    'one-hot': one_hot_encoding,
    'circular': circular_encoding,
    'target': target_encoding
}

results = []
for name, func in encodings.items():
    X_train, X_test, y_train, y_test = initialize_data(X, y)
    
    start = timer()
    X_train, X_test = func(X_train, X_test, y_train,
                           cols=['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 
                                 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 
                                 'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME'])
    fit_time = timer()
    
    reg = LinearRegression().fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    
    end = timer()
    
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    results.append({'MSE': f'{mse:.2f}', 
                    'RMSE (mn)': f'{mse**0.5:.2f}', 
                    'MAE (mn)': f'{mae:.2f}', 
                    'R2 (%)': f'{r2*100:.2f}', 
                    'fit_time (s)': f'{fit_time - start:.2f}', 
                    'pred_time (s)': f'{end - fit_time:.2f}', 
                    'total_time (s)': f'{end - start:.2f}'})

results = pd.DataFrame(results, index=encodings.keys())
results
# Out:
#          MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# label       23.00  1340.84   4.96     36.62         0.11          0.09
# count       23.18  1379.55   2.21     37.14         0.07          0.01
# one-hot     21.12  1125.24  20.24     33.54         0.19          1.09
# circular    23.02  1343.90   4.74     36.66         0.68          0.02
# target      21.23  1136.26  19.46     33.71         0.14          0.01
#
#          total_time (s)
# label              0.20
# count              0.09
# one-hot            1.28
# circular           0.71
# target             0.16

# %% [markdown]
# ## Outliers

# %%
X_train, X_test, y_train, y_test = initialize_data(X, y)

X_train, X_test = target_encoding(X_train, X_test, y_train,
                                  cols=['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 
                                        'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 
                                        'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME'])
print("With outliers:")
reg = LinearRegression().fit(X_train, y_train)
y_pred = reg.predict(X_test)
get_scores(y_test, y_pred, verbose=1)

print("\nWithout outliers in the training set:")
mask = np.abs(y_train - y_train.mean()) <= (3*y_train.std())
X_train_tmp = X_train[mask]
y_train_tmp = y_train[mask]
reg = LinearRegression().fit(X_train_tmp, y_train_tmp)
y_pred = reg.predict(X_test)
get_scores(y_test, y_pred)

print("\nWithout outliers in the whole dataset:")
mask = np.abs(y - y.mean()) <= (3*y.std())
X_temp = X[mask]
y_temp = y[mask]
X_train, X_test, y_train, y_test = initialize_data(X_temp, y_temp)
X_train, X_test = target_encoding(X_train, X_test, y_train,
                                  cols=['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 
                                        'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 
                                        'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME'])
reg = LinearRegression().fit(X_train, y_train)
y_pred = reg.predict(X_test)
_ = get_scores(y_test, y_pred)
# Out:
# With outliers:
# MSE: 1136.26, RMSE: 33.71 mn
# MAE: 21.23 mn
# R2: 19.46 %
#
# Without outliers in the training set:
# MSE: 1175.63, RMSE: 34.29 mn
# MAE: 20.24 mn
# R2: 16.67 %
#
# Without outliers in the whole dataset:
# MSE: 559.17, RMSE: 23.65 mn
# MAE: 16.87 mn
# R2: 19.34 %

# %% [markdown]
# ## 0/ Initialize data

# %%
X_train, X_test, y_train, y_test = initialize_data(X, y)

X_train, X_test = target_encoding(X_train, X_test, y_train,
                                  cols=['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 
                                        'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 
                                        'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME'])

# %% [markdown]
# ## 1/ Linear Regression

# %%
_ = test_model(X_train, X_test, y_train, y_test, LinearRegression)
# Out:
# --- LinearRegression ({'n_jobs': -1}) ---
# MSE: 1136.26, RMSE: 33.71 mn
# MAE: 21.23 mn
# R2: 19.46 %
# Fit time: 0.01s
# Pred time: 0.00s

# %% [markdown]
# ## 2/ Regression ridge

# %%
_ = test_model(X_train, X_test, y_train, y_test, Ridge, params={'alpha': 1})
# Out:
# --- Ridge ({'alpha': 1}) ---
# MSE: 1136.26, RMSE: 33.71 mn
# MAE: 21.23 mn
# R2: 19.46 %
# Fit time: 0.03s
# Pred time: 0.00s

# %%
_ = test_model(X_train, X_test, y_train, y_test, Ridge, with_cv=True, params_cv={'alpha': np.logspace(-5, 5, 11)}, verbose=2)
# Out:
# --- Ridge CV ---
# Testing: {'alpha': array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04, 1.e+05])}
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# {'alpha': 1e-05} - Score: 0.2121 - Time: 0.06s
# {'alpha': 0.0001} - Score: 0.2121 - Time: 0.06s
# {'alpha': 0.001} - Score: 0.2121 - Time: 0.06s
# {'alpha': 0.01} - Score: 0.2121 - Time: 0.06s
# {'alpha': 0.1} - Score: 0.2121 - Time: 0.06s
# {'alpha': 1.0} - Score: 0.2121 - Time: 0.06s
# {'alpha': 10.0} - Score: 0.2121 - Time: 0.06s
# {'alpha': 100.0} - Score: 0.2121 - Time: 0.06s
# {'alpha': 1000.0} - Score: 0.2120 - Time: 0.06s
# {'alpha': 10000.0} - Score: 0.2062 - Time: 0.06s
# {'alpha': 100000.0} - Score: 0.1289 - Time: 0.06s
# --- Ridge ({'alpha': 100.0}) ---
# MSE: 1136.22, RMSE: 33.71 mn
# MAE: 21.23 mn
# R2: 19.46 %
# Fit time: 0.01s
# Pred time: 0.00s

# %% [markdown]
# ## 3/ Lasso

# %%
_ = test_model(X_train, X_test, y_train, y_test, Lasso, params={'alpha': 1})
# Out:
# --- Lasso ({'alpha': 1}) ---
# MSE: 1138.10, RMSE: 33.74 mn
# MAE: 21.08 mn
# R2: 19.33 %
# Fit time: 0.01s
# Pred time: 0.00s

# %%
_ = test_model(X_train, X_test, y_train, y_test, Lasso, with_cv=True, params_cv={'alpha': np.logspace(-5, 5, 11)}, verbose=2)
# Out:
# --- Lasso CV ---
# Testing: {'alpha': array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04, 1.e+05])}
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# {'alpha': 1e-05} - Score: 0.2121 - Time: 0.12s
# {'alpha': 0.0001} - Score: 0.2121 - Time: 0.10s
# {'alpha': 0.001} - Score: 0.2121 - Time: 0.10s
# {'alpha': 0.01} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1} - Score: 0.2121 - Time: 0.08s
# {'alpha': 1.0} - Score: 0.2096 - Time: 0.08s
# {'alpha': 10.0} - Score: 0.0763 - Time: 0.06s
# {'alpha': 100.0} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0} - Score: -0.0001 - Time: 0.06s
# --- Lasso ({'alpha': 0.01}) ---
# MSE: 1136.24, RMSE: 33.71 mn
# MAE: 21.23 mn
# R2: 19.46 %
# Fit time: 0.02s
# Pred time: 0.00s

# %% [markdown]
# ## 4/ Elastic-Net

# %%
_ = test_model(X_train, X_test, y_train, y_test, ElasticNet, params={'alpha': 1, 'l1_ratio': 0.9})
# Out:
# --- ElasticNet ({'alpha': 1, 'l1_ratio': 0.9}) ---
# MSE: 1140.27, RMSE: 33.77 mn
# MAE: 21.04 mn
# R2: 19.17 %
# Fit time: 0.01s
# Pred time: 0.00s

# %%
_ = test_model(X_train, X_test, y_train, y_test, ElasticNet, with_cv=True, verbose=2,
               params_cv={'alpha': np.logspace(-3, 3, 7), 'l1_ratio': [.1, .5, .7, .9, .95, .99, 1]})
# Out:
# --- ElasticNet CV ---
# Testing: {'alpha': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03]), 'l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]}
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# {'alpha': 0.001, 'l1_ratio': 0.1} - Score: 0.2121 - Time: 0.11s
# {'alpha': 0.001, 'l1_ratio': 0.5} - Score: 0.2121 - Time: 0.10s
# {'alpha': 0.001, 'l1_ratio': 0.7} - Score: 0.2121 - Time: 0.10s
# {'alpha': 0.001, 'l1_ratio': 0.9} - Score: 0.2121 - Time: 0.10s
# {'alpha': 0.001, 'l1_ratio': 0.95} - Score: 0.2121 - Time: 0.10s
# {'alpha': 0.001, 'l1_ratio': 0.99} - Score: 0.2121 - Time: 0.10s
# {'alpha': 0.001, 'l1_ratio': 1} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01, 'l1_ratio': 0.1} - Score: 0.2121 - Time: 0.10s
# {'alpha': 0.01, 'l1_ratio': 0.5} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01, 'l1_ratio': 0.7} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01, 'l1_ratio': 0.9} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01, 'l1_ratio': 0.95} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01, 'l1_ratio': 0.99} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.01, 'l1_ratio': 1} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.1, 'l1_ratio': 0.1} - Score: 0.2109 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.5} - Score: 0.2117 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.7} - Score: 0.2119 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.9} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.95} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.99} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 1} - Score: 0.2121 - Time: 0.08s
# {'alpha': 1.0, 'l1_ratio': 0.1} - Score: 0.1746 - Time: 0.07s
# {'alpha': 1.0, 'l1_ratio': 0.5} - Score: 0.1901 - Time: 0.08s
# {'alpha': 1.0, 'l1_ratio': 0.7} - Score: 0.1988 - Time: 0.08s
# {'alpha': 1.0, 'l1_ratio': 0.9} - Score: 0.2069 - Time: 0.07s
# {'alpha': 1.0, 'l1_ratio': 0.95} - Score: 0.2084 - Time: 0.08s
# {'alpha': 1.0, 'l1_ratio': 0.99} - Score: 0.2094 - Time: 0.09s
# {'alpha': 1.0, 'l1_ratio': 1} - Score: 0.2096 - Time: 0.08s
# {'alpha': 10.0, 'l1_ratio': 0.1} - Score: 0.0488 - Time: 0.07s
# {'alpha': 10.0, 'l1_ratio': 0.5} - Score: 0.0410 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 0.7} - Score: 0.0389 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 0.9} - Score: 0.0501 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 0.95} - Score: 0.0593 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 0.99} - Score: 0.0719 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 1} - Score: 0.0763 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.1} - Score: 0.0009 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.05s
# {'alpha': 100.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.05s
# {'alpha': 1000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.06s
# --- ElasticNet ({'alpha': 0.01, 'l1_ratio': 0.5}) ---
# MSE: 1136.14, RMSE: 33.71 mn
# MAE: 21.22 mn
# R2: 19.47 %
# Fit time: 0.02s
# Pred time: 0.00s

# %% [markdown]
# ## 5/ Polynomial features

# %%
_ = test_model(X_train, X_test, y_train, y_test, LinearRegression, poly_features_degree=2)
# Out:
# --- LinearRegression with polynomial features ({'n_jobs': -1}) ---
# MSE: 1087.85, RMSE: 32.98 mn
# MAE: 20.31 mn
# R2: 22.89 %
# Fit time: 0.14s
# Pred time: 0.00s

# %%
_ = test_model(X_train, X_test, y_train, y_test, ElasticNet, poly_features_degree=2, with_cv=True, verbose=2, 
               params_cv={'alpha': np.logspace(-1, 4, 6), 'l1_ratio': [.1, .5, .7, .9, .95, .99, 1]})
# Out:
# --- ElasticNet CV ---
# Testing: {'alpha': array([1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04]), 'l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]}
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# {'alpha': 0.1, 'l1_ratio': 0.1} - Score: 0.2538 - Time: 6.55s
# {'alpha': 0.1, 'l1_ratio': 0.5} - Score: 0.2540 - Time: 3.72s
# {'alpha': 0.1, 'l1_ratio': 0.7} - Score: 0.2542 - Time: 3.02s
# {'alpha': 0.1, 'l1_ratio': 0.9} - Score: 0.2543 - Time: 2.49s
# {'alpha': 0.1, 'l1_ratio': 0.95} - Score: 0.2543 - Time: 2.43s
# {'alpha': 0.1, 'l1_ratio': 0.99} - Score: 0.2544 - Time: 2.38s
# {'alpha': 0.1, 'l1_ratio': 1} - Score: 0.2544 - Time: 2.35s
# {'alpha': 1.0, 'l1_ratio': 0.1} - Score: 0.2482 - Time: 2.16s
# {'alpha': 1.0, 'l1_ratio': 0.5} - Score: 0.2492 - Time: 1.50s
# {'alpha': 1.0, 'l1_ratio': 0.7} - Score: 0.2499 - Time: 1.33s
# {'alpha': 1.0, 'l1_ratio': 0.9} - Score: 0.2504 - Time: 1.14s
# {'alpha': 1.0, 'l1_ratio': 0.95} - Score: 0.2505 - Time: 1.13s
# {'alpha': 1.0, 'l1_ratio': 0.99} - Score: 0.2505 - Time: 1.13s
# {'alpha': 1.0, 'l1_ratio': 1} - Score: 0.2505 - Time: 1.11s
# {'alpha': 10.0, 'l1_ratio': 0.1} - Score: 0.2195 - Time: 0.68s
# {'alpha': 10.0, 'l1_ratio': 0.5} - Score: 0.2126 - Time: 0.62s
# {'alpha': 10.0, 'l1_ratio': 0.7} - Score: 0.2082 - Time: 0.67s
# {'alpha': 10.0, 'l1_ratio': 0.9} - Score: 0.2035 - Time: 0.77s
# {'alpha': 10.0, 'l1_ratio': 0.95} - Score: 0.2026 - Time: 0.63s
# {'alpha': 10.0, 'l1_ratio': 0.99} - Score: 0.2020 - Time: 0.67s
# {'alpha': 10.0, 'l1_ratio': 1} - Score: 0.2018 - Time: 0.70s
# {'alpha': 100.0, 'l1_ratio': 0.1} - Score: 0.0862 - Time: 0.44s
# {'alpha': 100.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.32s
# {'alpha': 100.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.32s
# {'alpha': 100.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.33s
# {'alpha': 100.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.32s
# {'alpha': 100.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.32s
# {'alpha': 100.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.32s
# {'alpha': 1000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.32s
# {'alpha': 1000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.32s
# {'alpha': 1000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.33s
# {'alpha': 1000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.32s
# {'alpha': 1000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.32s
# {'alpha': 1000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.33s
# {'alpha': 1000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.32s
# {'alpha': 10000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.33s
# {'alpha': 10000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.33s
# {'alpha': 10000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.32s
# {'alpha': 10000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.33s
# {'alpha': 10000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.32s
# {'alpha': 10000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.32s
# {'alpha': 10000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.33s
# --- ElasticNet with polynomial features ({'alpha': 0.1, 'l1_ratio': 1}) ---
# MSE: 1088.96, RMSE: 33.00 mn
# MAE: 20.30 mn
# R2: 22.81 %
# Fit time: 0.51s
# Pred time: 0.00s

# %%
_ = test_model(X_train, X_test, y_train, y_test, LinearRegression, poly_features_degree=3)
# Out:
# --- LinearRegression with polynomial features ({'n_jobs': -1}) ---
# MSE: 1075.30, RMSE: 32.79 mn
# MAE: 20.16 mn
# R2: 23.78 %
# Fit time: 0.80s
# Pred time: 0.01s

# %%
_ = test_model(X_train, X_test, y_train, y_test, LinearRegression, poly_features_degree=4)
# Out:
# --- LinearRegression with polynomial features ({'n_jobs': -1}) ---
# MSE: 1082.50, RMSE: 32.90 mn
# MAE: 20.11 mn
# R2: 23.27 %
# Fit time: 3.10s
# Pred time: 0.02s

# %%
_ = test_model(X_train, X_test, y_train, y_test, LinearRegression, poly_features_degree=5)
# Out:
# --- LinearRegression with polynomial features ({'n_jobs': -1}) ---
# MSE: 1580.35, RMSE: 39.75 mn
# MAE: 20.57 mn
# R2: -12.02 %
# Fit time: 15.58s
# Pred time: 0.04s

# %% [markdown]
# ## 6/ k-NN

# %%
_ = test_model(X_train, X_test, y_train, y_test, KNeighborsRegressor, params={'n_neighbors': 40})
# Out:
# --- KNeighborsRegressor ({'n_neighbors': 40, 'n_jobs': -1}) ---
# MSE: 1070.77, RMSE: 32.72 mn
# MAE: 19.87 mn
# R2: 24.10 %
# Fit time: 0.06s
# Pred time: 2.03s

# %%
_ = test_model(X_train, X_test, y_train, y_test, KNeighborsRegressor, with_cv=True, params_cv={'n_neighbors': np.arange(10, 51, 10)}, verbose=2)
# Out:
# --- KNeighborsRegressor CV ---
# Testing: {'n_neighbors': array([10, 20, 30, 40, 50])}
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# {'n_neighbors': 10, 'n_jobs': -1} - Score: 0.2363 - Time: 4.34s
# {'n_neighbors': 20, 'n_jobs': -1} - Score: 0.2560 - Time: 5.78s
# {'n_neighbors': 30, 'n_jobs': -1} - Score: 0.2607 - Time: 6.77s
# {'n_neighbors': 40, 'n_jobs': -1} - Score: 0.2603 - Time: 7.37s
# {'n_neighbors': 50, 'n_jobs': -1} - Score: 0.2597 - Time: 8.10s
# --- KNeighborsRegressor ({'n_neighbors': 30, 'n_jobs': -1}) ---
# MSE: 1070.43, RMSE: 32.72 mn
# MAE: 19.90 mn
# R2: 24.12 %
# Fit time: 0.06s
# Pred time: 1.66s

# %% [markdown]
# ## 7/ Bagging

# %%
_ = test_model(X_train, X_test, y_train, y_test, BaggingRegressor, params={'n_estimators': 100})
# Out:
# --- BaggingRegressor ({'n_estimators': 100, 'n_jobs': -1}) ---
# MSE: 1042.92, RMSE: 32.29 mn
# MAE: 19.72 mn
# R2: 26.07 %
# Fit time: 7.72s
# Pred time: 2.25s

# %% [markdown]
# ## 8/ Random Forest

# %%
_ = test_model(X_train, X_test, y_train, y_test, RandomForestRegressor, params={'n_estimators': 100, 'max_features': 3, 
                                                'min_samples_split': 10})
# Out:
# --- RandomForestRegressor ({'n_estimators': 100, 'max_features': 3, 'min_samples_split': 10, 'n_jobs': -1}) ---
# MSE: 994.10, RMSE: 31.53 mn
# MAE: 19.11 mn
# R2: 29.53 %
# Fit time: 1.77s
# Pred time: 0.11s

# %%
_ = test_model(X_train, X_test, y_train, y_test, RandomForestRegressor, with_cv=True, 
           params_cv={'n_estimators': np.arange(100, 101, 100), 
                      'max_features': np.arange(2, 5),
                      'min_samples_split': [2, 5, 10, 20, 30]}, 
           n_folds=4, verbose=2)
# Out:
# --- RandomForestRegressor CV ---
# Testing: {'n_estimators': array([100]), 'max_features': array([2, 3, 4]), 'min_samples_split': [2, 5, 10, 20, 30]}
# Fitting 4 folds for each of 15 candidates, totalling 60 fits
# {'n_estimators': 100, 'max_features': 2, 'min_samples_split': 2, 'n_jobs': -1} - Score: 0.3034 - Time: 6.42s
# {'n_estimators': 100, 'max_features': 2, 'min_samples_split': 5, 'n_jobs': -1} - Score: 0.3109 - Time: 4.98s
# {'n_estimators': 100, 'max_features': 2, 'min_samples_split': 10, 'n_jobs': -1} - Score: 0.3110 - Time: 4.41s
# {'n_estimators': 100, 'max_features': 2, 'min_samples_split': 20, 'n_jobs': -1} - Score: 0.3075 - Time: 3.98s
# {'n_estimators': 100, 'max_features': 2, 'min_samples_split': 30, 'n_jobs': -1} - Score: 0.3021 - Time: 3.67s
# {'n_estimators': 100, 'max_features': 3, 'min_samples_split': 2, 'n_jobs': -1} - Score: 0.2991 - Time: 7.76s
# {'n_estimators': 100, 'max_features': 3, 'min_samples_split': 5, 'n_jobs': -1} - Score: 0.3067 - Time: 6.20s
# {'n_estimators': 100, 'max_features': 3, 'min_samples_split': 10, 'n_jobs': -1} - Score: 0.3118 - Time: 5.52s
# {'n_estimators': 100, 'max_features': 3, 'min_samples_split': 20, 'n_jobs': -1} - Score: 0.3109 - Time: 5.04s
# {'n_estimators': 100, 'max_features': 3, 'min_samples_split': 30, 'n_jobs': -1} - Score: 0.3083 - Time: 4.75s
# {'n_estimators': 100, 'max_features': 4, 'min_samples_split': 2, 'n_jobs': -1} - Score: 0.2945 - Time: 9.55s
# {'n_estimators': 100, 'max_features': 4, 'min_samples_split': 5, 'n_jobs': -1} - Score: 0.3032 - Time: 7.84s
# {'n_estimators': 100, 'max_features': 4, 'min_samples_split': 10, 'n_jobs': -1} - Score: 0.3094 - Time: 6.91s
# {'n_estimators': 100, 'max_features': 4, 'min_samples_split': 20, 'n_jobs': -1} - Score: 0.3096 - Time: 6.37s
# {'n_estimators': 100, 'max_features': 4, 'min_samples_split': 30, 'n_jobs': -1} - Score: 0.3084 - Time: 5.94s
# --- RandomForestRegressor ({'n_estimators': 100, 'max_features': 3, 'min_samples_split': 10, 'n_jobs': -1}) ---
# MSE: 995.59, RMSE: 31.55 mn
# MAE: 19.12 mn
# R2: 29.43 %
# Fit time: 1.63s
# Pred time: 0.11s

# %% [markdown]
# ## 9/ Gradient Boosting

# %%
_ = test_model(X_train, X_test, y_train, y_test, GradientBoostingRegressor, params={'n_estimators': 100, 'max_features': 3})
# Out:
# --- GradientBoostingRegressor ({'n_estimators': 100, 'max_features': 3}) ---
# MSE: 1054.04, RMSE: 32.47 mn
# MAE: 19.94 mn
# R2: 25.29 %
# Fit time: 0.78s
# Pred time: 0.02s

# %%
_ = test_model(X_train, X_test, y_train, y_test, GradientBoostingRegressor, with_cv=True, 
           params_cv={'n_estimators': np.arange(50, 201, 50), 
                      'max_features': np.arange(2, 8)}, 
           n_folds=3, verbose=2)
# Out:
# --- GradientBoostingRegressor CV ---
# Testing: {'n_estimators': array([ 50, 100, 150, 200]), 'max_features': array([2, 3, 4, 5, 6, 7])}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# {'n_estimators': 50, 'max_features': 2} - Score: 0.2409 - Time: 0.77s
# {'n_estimators': 50, 'max_features': 3} - Score: 0.2565 - Time: 0.92s
# {'n_estimators': 50, 'max_features': 4} - Score: 0.2607 - Time: 1.06s
# {'n_estimators': 50, 'max_features': 5} - Score: 0.2644 - Time: 1.18s
# {'n_estimators': 50, 'max_features': 6} - Score: 0.2633 - Time: 1.30s
# {'n_estimators': 50, 'max_features': 7} - Score: 0.2634 - Time: 1.44s
# {'n_estimators': 100, 'max_features': 2} - Score: 0.2591 - Time: 1.41s
# {'n_estimators': 100, 'max_features': 3} - Score: 0.2679 - Time: 1.64s
# {'n_estimators': 100, 'max_features': 4} - Score: 0.2694 - Time: 1.89s
# {'n_estimators': 100, 'max_features': 5} - Score: 0.2702 - Time: 2.14s
# {'n_estimators': 100, 'max_features': 6} - Score: 0.2702 - Time: 2.37s
# {'n_estimators': 100, 'max_features': 7} - Score: 0.2708 - Time: 2.59s
# {'n_estimators': 150, 'max_features': 2} - Score: 0.2701 - Time: 2.08s
# {'n_estimators': 150, 'max_features': 3} - Score: 0.2719 - Time: 2.43s
# {'n_estimators': 150, 'max_features': 4} - Score: 0.2746 - Time: 2.77s
# {'n_estimators': 150, 'max_features': 5} - Score: 0.2748 - Time: 3.15s
# {'n_estimators': 150, 'max_features': 6} - Score: 0.2771 - Time: 3.58s
# {'n_estimators': 150, 'max_features': 7} - Score: 0.2755 - Time: 3.93s
# {'n_estimators': 200, 'max_features': 2} - Score: 0.2706 - Time: 2.76s
# {'n_estimators': 200, 'max_features': 3} - Score: 0.2744 - Time: 3.25s
# {'n_estimators': 200, 'max_features': 4} - Score: 0.2781 - Time: 3.78s
# {'n_estimators': 200, 'max_features': 5} - Score: 0.2793 - Time: 4.19s
# {'n_estimators': 200, 'max_features': 6} - Score: 0.2784 - Time: 4.66s
# {'n_estimators': 200, 'max_features': 7} - Score: 0.2789 - Time: 5.31s
# --- GradientBoostingRegressor ({'n_estimators': 200, 'max_features': 5}) ---
# MSE: 1038.25, RMSE: 32.22 mn
# MAE: 19.71 mn
# R2: 26.41 %
# Fit time: 2.08s
# Pred time: 0.03s

# %% [markdown]
# ## Run all models for one airline

# %%
# %%timeit -n1 -r1

models = {
    'Linear Regression': {'model': LinearRegression},
    'Ridge': {'model': Ridge, 'params': {'alpha': 1}, 
              'with_cv': True, 'params_cv': {'alpha': np.logspace(-5, 5, 11)}},
    'Lasso': {'model': Lasso, 'params': {'alpha': 1}, 
              'with_cv': True, 'params_cv': {'alpha': np.logspace(-5, 5, 11)}},
    'Elastic Net': {'model': ElasticNet, 'params': {'alpha': 1, 'l1_ratio': 0.9},
                    'with_cv': True, 'params_cv': {'alpha': np.logspace(-2, 5, 8),
                                                   'l1_ratio': [.1, .5, .7, .9, .95, .99, 1]}},
    'Polynomial Features': {'model': LinearRegression, 'poly_features_degree': 3},
    'k-Nearest Neighbors': {'model': KNeighborsRegressor, 'params': {'n_neighbors': 30}, 'with_cv': False,
                            'params_cv': {'n_neighbors': np.arange(10, 51, 10)}},  
    'Bagging Regressor': {'model': BaggingRegressor, 'params': {'n_estimators': 50}},
    'Random Forest': {'model': RandomForestRegressor, 'params': {'n_estimators': 100, 'max_features': 3, 'min_samples_leaf': 10}},
    'Gradient Boosting': {'model': GradientBoostingRegressor, 'params': {'n_estimators': 100, 'max_features': 3}}
}

airline = 'VX'
print(f"---------- Start Airline : {airline} ---------------")
start = timer()
X = pd.read_csv(f'C:/Users/Serphone/Data/OCR_DS_P4/AIRLINE_DATASETS/{airline}.csv')
y = X.pop('ARR_DELAY')

X_train, X_test, y_train, y_test = initialize_data(X, y)

X_train, X_test = target_encoding(X_train, X_test, y_train,
                                  cols=['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 
                                        'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 
                                        'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME'])

results = []
infos = {
    'y_test_size': y_test.shape[0],
    'y_test_mean': np.mean(y_test),
    'y_test_sum': np.sum(y_test),
    'y_test_sum_squared': np.sum(y_test ** 2)
}

for name, params in models.items():   
    results.append(test_model(X_train, X_test, y_train, y_test, verbose=2, **params))

end = timer()
print(f"---------- End Airline : {airline} - {end-start:.2f}s ---------------")

display(pd.DataFrame(results, index=models.keys()))
# Out:
# ---------- Start Airline : VX ---------------
# --- LinearRegression ({'n_jobs': -1}) ---
# MSE: 1136.26, RMSE: 33.71 mn
# MAE: 21.23 mn
# R2: 19.46 %
# Fit time: 0.01s
# Pred time: 0.00s
# --- Ridge CV ---
# Testing: {'alpha': array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04, 1.e+05])}
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# {'alpha': 1e-05} - Score: 0.2121 - Time: 0.13s
# {'alpha': 0.0001} - Score: 0.2121 - Time: 0.05s
# {'alpha': 0.001} - Score: 0.2121 - Time: 0.06s
# {'alpha': 0.01} - Score: 0.2121 - Time: 0.05s
# {'alpha': 0.1} - Score: 0.2121 - Time: 0.05s
# {'alpha': 1.0} - Score: 0.2121 - Time: 0.06s
# {'alpha': 10.0} - Score: 0.2121 - Time: 0.06s
# {'alpha': 100.0} - Score: 0.2121 - Time: 0.06s
# {'alpha': 1000.0} - Score: 0.2120 - Time: 0.06s
# {'alpha': 10000.0} - Score: 0.2062 - Time: 0.06s
# {'alpha': 100000.0} - Score: 0.1289 - Time: 0.06s
# --- Ridge ({'alpha': 100.0}) ---
# MSE: 1136.22, RMSE: 33.71 mn
# MAE: 21.23 mn
# R2: 19.46 %
# Fit time: 0.01s
# Pred time: 0.00s
# --- Lasso CV ---
# Testing: {'alpha': array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04, 1.e+05])}
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# {'alpha': 1e-05} - Score: 0.2121 - Time: 0.14s
# {'alpha': 0.0001} - Score: 0.2121 - Time: 0.11s
# {'alpha': 0.001} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1} - Score: 0.2121 - Time: 0.08s
# {'alpha': 1.0} - Score: 0.2096 - Time: 0.08s
# {'alpha': 10.0} - Score: 0.0763 - Time: 0.06s
# {'alpha': 100.0} - Score: -0.0001 - Time: 0.05s
# {'alpha': 1000.0} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0} - Score: -0.0001 - Time: 0.06s
# --- Lasso ({'alpha': 0.01}) ---
# MSE: 1136.24, RMSE: 33.71 mn
# MAE: 21.23 mn
# R2: 19.46 %
# Fit time: 0.02s
# Pred time: 0.00s
# --- ElasticNet CV ---
# Testing: {'alpha': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05]), 'l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]}
# Fitting 5 folds for each of 56 candidates, totalling 280 fits
# {'alpha': 0.01, 'l1_ratio': 0.1} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01, 'l1_ratio': 0.5} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.01, 'l1_ratio': 0.7} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.01, 'l1_ratio': 0.9} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.01, 'l1_ratio': 0.95} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01, 'l1_ratio': 0.99} - Score: 0.2121 - Time: 0.09s
# {'alpha': 0.01, 'l1_ratio': 1} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.1} - Score: 0.2109 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.5} - Score: 0.2117 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.7} - Score: 0.2119 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.9} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.95} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 0.99} - Score: 0.2121 - Time: 0.08s
# {'alpha': 0.1, 'l1_ratio': 1} - Score: 0.2121 - Time: 0.08s
# {'alpha': 1.0, 'l1_ratio': 0.1} - Score: 0.1746 - Time: 0.07s
# {'alpha': 1.0, 'l1_ratio': 0.5} - Score: 0.1901 - Time: 0.08s
# {'alpha': 1.0, 'l1_ratio': 0.7} - Score: 0.1988 - Time: 0.07s
# {'alpha': 1.0, 'l1_ratio': 0.9} - Score: 0.2069 - Time: 0.07s
# {'alpha': 1.0, 'l1_ratio': 0.95} - Score: 0.2084 - Time: 0.08s
# {'alpha': 1.0, 'l1_ratio': 0.99} - Score: 0.2094 - Time: 0.08s
# {'alpha': 1.0, 'l1_ratio': 1} - Score: 0.2096 - Time: 0.07s
# {'alpha': 10.0, 'l1_ratio': 0.1} - Score: 0.0488 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 0.5} - Score: 0.0410 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 0.7} - Score: 0.0389 - Time: 0.07s
# {'alpha': 10.0, 'l1_ratio': 0.9} - Score: 0.0501 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 0.95} - Score: 0.0593 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 0.99} - Score: 0.0719 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 1} - Score: 0.0763 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.1} - Score: 0.0009 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.05s
# {'alpha': 100.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.06s
# {'alpha': 1000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.05s
# {'alpha': 1000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.05s
# {'alpha': 1000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.05s
# {'alpha': 10000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.05s
# {'alpha': 100000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.06s
# --- ElasticNet ({'alpha': 0.01, 'l1_ratio': 0.5}) ---
# MSE: 1136.14, RMSE: 33.71 mn
# MAE: 21.22 mn
# R2: 19.47 %
# Fit time: 0.02s
# Pred time: 0.00s
# --- LinearRegression with polynomial features ({'n_jobs': -1}) ---
# MSE: 1075.30, RMSE: 32.79 mn
# MAE: 20.16 mn
# R2: 23.78 %
# Fit time: 0.77s
# Pred time: 0.01s
# --- KNeighborsRegressor ({'n_neighbors': 30, 'n_jobs': -1}) ---
# MSE: 1070.43, RMSE: 32.72 mn
# MAE: 19.90 mn
# R2: 24.12 %
# Fit time: 0.06s
# Pred time: 1.59s
# --- BaggingRegressor ({'n_estimators': 50, 'n_jobs': -1}) ---
# MSE: 1055.10, RMSE: 32.48 mn
# MAE: 19.81 mn
# R2: 25.21 %
# Fit time: 4.30s
# Pred time: 1.43s
# --- RandomForestRegressor ({'n_estimators': 100, 'max_features': 3, 'min_samples_leaf': 10, 'n_jobs': -1}) ---
# MSE: 1002.51, RMSE: 31.66 mn
# MAE: 19.09 mn
# R2: 28.94 %
# Fit time: 1.41s
# Pred time: 0.11s
# --- GradientBoostingRegressor ({'n_estimators': 100, 'max_features': 3}) ---
# MSE: 1055.27, RMSE: 32.48 mn
# MAE: 19.96 mn
# R2: 25.20 %
# Fit time: 0.79s
# Pred time: 0.03s
# ---------- End Airline : VX - 16.48s ---------------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      21.23  1136.26  19.46     33.71         0.01
# Ridge                  21.23  1136.22  19.46     33.71         0.01
# Lasso                  21.23  1136.24  19.46     33.71         0.02
# Elastic Net            21.22  1136.14  19.47     33.71         0.02
# Polynomial Features    20.16  1075.30  23.78     32.79         0.77
# k-Nearest Neighbors    19.90  1070.43  24.12     32.72         0.06
# Bagging Regressor      19.81  1055.10  25.21     32.48         4.30
# Random Forest          19.09  1002.51  28.94     31.66         1.41
# Gradient Boosting      19.96  1055.27  25.20     32.48         0.79
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.01
# Ridge                        0.00           0.01
# Lasso                        0.00           0.02
# Elastic Net                  0.00           0.02
# Polynomial Features          0.01           0.77
# k-Nearest Neighbors          1.59           1.65
# Bagging Regressor            1.43           5.73
# Random Forest                0.11           1.52
# Gradient Boosting            0.03           0.82
# 16.5 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## Run all models for all airlines

# %%
airlines = ['AA', 'AS', 'B6', 'DL', 'EV', 'F9', 
            'HA', 'NK', 'OO', 'UA', 'VX', 'WN']

models = {
    'Linear Regression': {'model': LinearRegression},
    'Ridge': {'model': Ridge, 'params': {'alpha': 1}, 'with_cv': True, 
              'params_cv': {'alpha': np.logspace(-5, 5, 11)}},
    'Lasso': {'model': Lasso, 'params': {'alpha': 1}, 'with_cv': True, 
              'params_cv': {'alpha': np.logspace(-5, 5, 11)}},
    'Elastic Net': {'model': ElasticNet, 'params': {'alpha': 1, 'l1_ratio': 0.9},
                    'with_cv': True, 'params_cv': {'alpha': np.logspace(-2, 5, 8),
                                                   'l1_ratio': [.1, .5, .7, .9, .95, .99, 1]}},
    'Polynomial Features': {'model': LinearRegression, 'poly_features_degree': 3},
    'k-Nearest Neighbors': {'model': KNeighborsRegressor, 'params': {'n_neighbors': 30}},  
    'Bagging Regressor': {'model': BaggingRegressor, 'params': {'n_estimators': 50}},
    'Random Forest': {'model': RandomForestRegressor, 
                      'params': {'n_estimators': 100, 'max_features': 3, 'min_samples_leaf': 10}},
    'Gradient Boosting': {'model': GradientBoostingRegressor, 'params': {'n_estimators': 100, 'max_features': 3}}
}

results = {}
infos = {}
for airline in airlines:
    print(f"---------- Start Airline : {airline} ---------------")
    start = timer()
    X = pd.read_csv(f'C:/Users/Serphone/Data/OCR_DS_P4/AIRLINE_DATASETS/{airline}.csv')
    y = X.pop('ARR_DELAY')
    
    X_train, X_test, y_train, y_test = initialize_data(X, y)

    X_train, X_test = target_encoding(X_train, X_test, y_train,
                                      cols=['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 
                                            'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 
                                            'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME'])
    
    results[airline] = []
    infos[airline] = {
        'y_test_size': y_test.shape[0],
        'y_test_mean': np.mean(y_test),
        'y_test_sum': np.sum(y_test),
        'y_test_sum_squared': np.sum(y_test ** 2)
    }
    
    for name, params in models.items():   
        results[airline].append(test_model(X_train, X_test, y_train, y_test, verbose=2, **params))
    
    end = timer()
    print(f"---------- End Airline : {airline} - {end-start:.2f}s ---------------")
# Out:
# ---------- Start Airline : AA ---------------
# --- LinearRegression ({'n_jobs': -1}) ---
# MSE: 1970.28, RMSE: 44.39 mn
# MAE: 21.85 mn
# R2: 5.95 %
# Fit time: 0.17s
# Pred time: 0.00s
# --- Ridge CV ---
# Testing: {'alpha': array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04, 1.e+05])}
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# {'alpha': 1e-05} - Score: 0.0652 - Time: 0.79s
# {'alpha': 0.0001} - Score: 0.0652 - Time: 0.76s
# {'alpha': 0.001} - Score: 0.0652 - Time: 0.76s
# {'alpha': 0.01} - Score: 0.0652 - Time: 0.74s
# {'alpha': 0.1} - Score: 0.0652 - Time: 0.74s
# {'alpha': 1.0} - Score: 0.0652 - Time: 0.74s
# {'alpha': 10.0} - Score: 0.0652 - Time: 0.76s
# {'alpha': 100.0} - Score: 0.0652 - Time: 0.77s
# {'alpha': 1000.0} - Score: 0.0652 - Time: 0.76s
# {'alpha': 10000.0} - Score: 0.0652 - Time: 0.75s
# {'alpha': 100000.0} - Score: 0.0640 - Time: 0.76s
# --- Ridge ({'alpha': 100.0}) ---
# MSE: 1970.28, RMSE: 44.39 mn
# MAE: 21.85 mn
# R2: 5.95 %
# Fit time: 0.09s
# Pred time: 0.00s
# --- Lasso CV ---
# Testing: {'alpha': array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04, 1.e+05])}
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# {'alpha': 1e-05} - Score: 0

# {'alpha': 10.0, 'l1_ratio': 0.5} - Score: 0.0003 - Time: 0.07s
# {'alpha': 10.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.07s
# {'alpha': 10.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.07s
# {'alpha': 10.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.07s
# {'alpha': 10.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.07s
# {'alpha': 100.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.08s
# {'alpha': 100.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.07s
# {'alpha': 100.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.07s
# {'alpha': 100.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.07s
# {'alpha': 100.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.07s
# {'alpha': 100.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.07s
# {'alpha': 100.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.07s
# {'alpha': 1000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.07s
# {'alpha': 1000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.07s
# {'alpha': 1000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.07s
# {'alpha': 1000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.07s
# {'alpha': 1000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.07s
# {'alpha': 1000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.07s
# {'alpha': 1000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.07s
# {'alpha': 10000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.07s
# {'alpha': 10000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.06s
# {'alpha': 10000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.1} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.5} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.7} - Score: -0.0001 - Time: 0.07s
# {'alpha': 100000.0, 'l1_ratio': 0.9} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.95} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 0.99} - Score: -0.0001 - Time: 0.06s
# {'alpha': 100000.0, 'l1_ratio': 1} - Score: -0.0001 - Time: 0.06s
# --- ElasticNet ({'alpha': 0.1, 'l1_ratio': 1}) ---
# MSE: 636.94, RMSE: 25.24 mn
# MAE: 9.70 mn
# R2: 2.05 %
# Fit time: 0.02s
# Pred time: 0.00s
# --- LinearRegression with polynomial features ({'n_jobs': -1}) ---
# MSE: 754.92, RMSE: 27.48 mn
# MAE: 10.09 mn
# R2: -16.10 %
# Fit time: 0.97s
# Pred time: 0.01s
# --- KNeighborsRegressor ({'n_neighbors': 30, 'n_jobs': -1}) ---
# MSE: 645.34, RMSE: 25.40 mn
# MAE: 9.52 mn
# R2: 0.75 %
# Fit time: 0.11s
# Pred time: 2.19s
# --- BaggingRegressor ({'n_estimators': 50, 'n_jobs': -1}) ---
# MSE: 764.73, RMSE: 27.65 mn
# MAE: 10.11 mn
# R2: -17.61 %
# Fit time: 5.00s
# Pred time: 1.56s
# --- RandomForestRegressor ({'n_estimators': 100, 'max_features': 3, 'min_samples_leaf': 10, 'n_jobs': -1}) ---
# MSE: 651.27, RMSE: 25.52 mn
# MAE: 9.35 mn
# R2: -0.16 %
# Fit time: 1.82s
# Pred time: 0.11s
# --- GradientBoostingRegressor ({'n_estimators': 100, 'max_features': 3}) ---
# MSE: 699.54, RMSE: 26.45 mn
# MAE: 9.59 mn
# R2: -7.58 %
# Fit time: 0.83s
# Pred time: 0.01s
# ---------- End Airline : HA - 19.67s ---------------
# ---------- Start Airline : NK ---------------
# --- LinearRegression ({'n_jobs': -1}) ---
# MSE: 1914.10, RMSE: 43.75 mn
# MAE: 24.48 mn
# R2: 8.39 %
# Fit time: 0.02s
# Pred time: 0.00s
# --- Ridge CV ---
# Testing: {'alpha': array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04, 1.e+05])}
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# {'alpha': 1e-05} - Score: 0.1062 - Time: 0.11s
# {'alpha': 0.0001} - Score: 0.1062 - Time: 0.11s
# {'alpha': 0.001} - Score: 0.1062 - Time: 0.11s
# {'alpha': 0.01} - Score: 0.1062 - Time: 0.11s
# {'alpha': 0.1} - Score: 0.1062 - Time: 0.11s
# {'alpha': 1.0} - Score: 0.1062 - Time: 0.11s
# {'alpha': 10.0} - Score: 0.1062 - Time: 0.11s
# {'alpha': 100.0} - Score: 0.1062 - Time: 0.11s
# {'alpha': 1000.0} - Score: 0.1061 - Time: 0.12s
# {'alpha': 10000.0} - Score: 0.1051 - Time: 0.11s
# {'alpha': 100000.0} - Score: 0.0842 - Time: 0.11s
# --- Ridge ({'alpha': 100.0}) ---
# MSE: 1914.07, RMSE: 43.75 mn
# MAE: 24.47 mn
# R2: 8.39 %
# Fit time: 0.01s
# Pred time: 0.00s
# --- Lasso CV ---
# ...
# {'alpha': 100.0, 'l1_ratio': 0.99} - Score: -0.0000 - Time: 0.50s
# {'alpha': 100.0, 'l1_ratio': 1} - Score: -0.0000 - Time: 0.50s
# {'alpha': 1000.0, 'l1_ratio': 0.1} - Score: -0.0000 - Time: 0.51s
# {'alpha': 1000.0, 'l1_ratio': 0.5} - Score: -0.0000 - Time: 0.50s
# {'alpha': 1000.0, 'l1_ratio': 0.7} - Score: -0.0000 - Time: 0.50s
# {'alpha': 1000.0, 'l1_ratio': 0.9} - Score: -0.0000 - Time: 0.50s
# {'alpha': 1000.0, 'l1_ratio': 0.95} - Score: -0.0000 - Time: 0.50s
# {'alpha': 1000.0, 'l1_ratio': 0.99} - Score: -0.0000 - Time: 0.51s
# {'alpha': 1000.0, 'l1_ratio': 1} - Score: -0.0000 - Time: 0.50s
# {'alpha': 10000.0, 'l1_ratio': 0.1} - Score: -0.0000 - Time: 0.50s
# {'alpha': 10000.0, 'l1_ratio': 0.5} - Score: -0.0000 - Time: 0.50s
# {'alpha': 10000.0, 'l1_ratio': 0.7} - Score: -0.0000 - Time: 0.50s
# {'alpha': 10000.0, 'l1_ratio': 0.9} - Score: -0.0000 - Time: 0.50s
# {'alpha': 10000.0, 'l1_ratio': 0.95} - Score: -0.0000 - Time: 0.51s
# {'alpha': 10000.0, 'l1_ratio': 0.99} - Score: -0.0000 - Time: 0.50s
# {'alpha': 10000.0, 'l1_ratio': 1} - Score: -0.0000 - Time: 0.50s
# {'alpha': 100000.0, 'l1_ratio': 0.1} - Score: -0.0000 - Time: 0.50s
# {'alpha': 100000.0, 'l1_ratio': 0.5} - Score: -0.0000 - Time: 0.49s
# {'alpha': 100000.0, 'l1_ratio': 0.7} - Score: -0.0000 - Time: 0.55s
# {'alpha': 100000.0, 'l1_ratio': 0.9} - Score: -0.0000 - Time: 0.51s
# {'alpha': 100000.0, 'l1_ratio': 0.95} - Score: -0.0000 - Time: 0.51s
# {'alpha': 100000.0, 'l1_ratio': 0.99} - Score: -0.0000 - Time: 0.50s
# {'alpha': 100000.0, 'l1_ratio': 1} - Score: -0.0000 - Time: 0.50s
# --- ElasticNet ({'alpha': 0.01, 'l1_ratio': 1}) ---
# MSE: 1796.50, RMSE: 42.39 mn
# MAE: 23.30 mn
# R2: 7.23 %
# Fit time: 0.18s
# Pred time: 0.00s
# --- LinearRegression with polynomial features ({'n_jobs': -1}) ---
# MSE: 1776.19, RMSE: 42.14 mn
# MAE: 22.87 mn
# R2: 8.28 %
# Fit time: 6.84s
# Pred time: 0.04s
# --- KNeighborsRegressor ({'n_neighbors': 30, 'n_jobs': -1}) ---
# MSE:
0, 'l1_ratio': 1} - Score: -0.0000 - Time: 1.27s
# {'alpha': 1000.0, 'l1_ratio': 0.1} - Score: -0.0000 - Time: 1.27s
# {'alpha': 1000.0, 'l1_ratio': 0.5} - Score: -0.0000 - Time: 1.28s
# {'alpha': 1000.0, 'l1_ratio': 0.7} - Score: -0.0000 - Time: 1.25s
# {'alpha': 1000.0, 'l1_ratio': 0.9} - Score: -0.0000 - Time: 1.27s
# {'alpha': 1000.0, 'l1_ratio': 0.95} - Score: -0.0000 - Time: 1.26s
# {'alpha': 1000.0, 'l1_ratio': 0.99} - Score: -0.0000 - Time: 1.27s
# {'alpha': 1000.0, 'l1_ratio': 1} - Score: -0.0000 - Time: 1.27s
# {'alpha': 10000.0, 'l1_ratio': 0.1} - Score: -0.0000 - Time: 1.26s
# {'alpha': 10000.0, 'l1_ratio': 0.5} - Score: -0.0000 - Time: 1.27s
# {'alpha': 10000.0, 'l1_ratio': 0.7} - Score: -0.0000 - Time: 1.26s
# {'alpha': 10000.0, 'l1_ratio': 0.9} - Score: -0.0000 - Time: 1.27s
# {'alpha': 10000.0, 'l1_ratio': 0.95} - Score: -0.0000 - Time: 1.26s
# {'alpha': 10000.0, 'l1_ratio': 0.99} - Score: -0.0000 - Time: 1.27s
# {'alpha': 10000.0, 'l1_ratio': 1} - Score: -0.0000 - Time: 1.26s
# {'alpha': 100000.0, 'l1_ratio': 0.1} - Score: -0.0000 - Time: 1.26s
# {'alpha': 100000.0, 'l1_ratio': 0.5} - Score: -0.0000 - Time: 1.25s
# {'alpha': 100000.0, 'l1_ratio': 0.7} - Score: -0.0000 - Time: 1.40s
# {'alpha': 100000.0, 'l1_ratio': 0.9} - Score: -0.0000 - Time: 1.25s
# {'alpha': 100000.0, 'l1_ratio': 0.95} - Score: -0.0000 - Time: 1.26s
# {'alpha': 100000.0, 'l1_ratio': 0.99} - Score: -0.0000 - Time: 1.27s
# {'alpha': 100000.0, 'l1_ratio': 1} - Score: -0.0000 - Time: 1.27s
# --- ElasticNet ({'alpha': 0.01, 'l1_ratio': 1}) ---
# MSE: 839.45, RMSE: 28.97 mn
# MAE: 16.56 mn
# R2: 12.88 %
# Fit time: 1.82s
# Pred time: 0.01s
# --- LinearRegression with polynomial features ({'n_jobs': -1}) ---
# MSE: 813.21, RMSE: 28.52 mn
# MAE: 16.08 mn
# R2: 15.60 %
# Fit time: 15.90s
# Pred time: 0.09s
# --- KNeighborsRegressor ({'n_neighbors': 30, 'n_jobs': -1}) ---
# MSE: 800.84, RMSE: 28.30 mn
# MAE: 16.01 mn
# R2: 16.88 %
# Fit time: 3.51s
# Pred time: 62.13s
# --- BaggingRegressor ({'n_estimators': 50, 'n_jobs': -1}) ---
# MSE: 776.47, RMSE: 27.87 mn
# MAE: 16.07 mn
# R2: 19.41 %
# Fit time: 668.13s
# Pred time: 226.34s
# --- RandomForestRegressor ({'n_estimators': 100, 'max_features': 3, 'min_samples_leaf': 10, 'n_jobs': -1}) ---
# MSE: 749.65, RMSE: 27.38 mn
# MAE: 15.25 mn
# R2: 22.20 %
# Fit time: 51.94s
# Pred time: 2.62s
# --- GradientBoostingRegressor ({'n_estimators': 100, 'max_features': 3}) ---
# MSE: 812.14, RMSE: 28.50 mn
# MAE: 16.05 mn
# R2: 15.71 %
# Fit time: 48.95s
# Pred time: 0.35s
# ---------- End Airline : WN - 1345.58s ---------------

# %% [markdown]
# ## Results by airline

# %%
for airline in airlines:
    print(f"------ Results for airline: {airline} -------")
    display(pd.DataFrame(results[airline], index=models.keys()))
    print("\n")
# Out:
# ------ Results for airline: AA -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      21.85  1970.28   5.95     44.39         0.17
# Ridge                  21.85  1970.28   5.95     44.39         0.09
# Lasso                  21.85  1970.27   5.95     44.39         0.36
# Elastic Net            21.85  1970.27   5.95     44.39         0.36
# Polynomial Features    21.48  1952.00   6.82     44.18        12.12
# k-Nearest Neighbors    21.71  1965.43   6.18     44.33         2.56
# Bagging Regressor      22.39  2008.27   4.13     44.81       184.55
# Random Forest          20.78  1873.72  10.55     43.29        37.58
# Gradient Boosting      21.45  1947.99   7.01     44.14        32.15
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.18
# Ridge                        0.00           0.10
# Lasso                        0.00           0.37
# Elastic Net                  0.00           0.37
# Polynomial Features          0.06          12.19
# k-Nearest Neighbors         71.67          74.23
# Bagging Regressor          121.58         306.13
# Random Forest                1.56          39.14
# Gradient Boosting            0.23          32.38
# ------ Results for airline: AS -------
#                     MAE (mn)     MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      14.78  686.01   6.67     26.19         0.11
# Ridge                  14.78  685.91   6.69     26.19         0.02
# Lasso                  14.78  685.96   6.68     26.19         0.04
# Elastic Net            14.78  685.96   6.68     26.19         0.04
# Polynomial Features    14.71  682.04   7.21     26.12         2.20
# k-Nearest Neighbors    14.82  688.56   6.32     26.24         0.28
# Bagging Regressor      15.16  713.96   2.87     26.72        11.03
# Random Forest          14.24  659.17  10.32     25.67         4.83
# Gradient Boosting      14.64  679.07   7.62     26.06         3.18
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.11
# Ridge                        0.00           0.02
# Lasso                        0.00           0.05
# Elastic Net                  0.00           0.05
# Polynomial Features          0.01           2.21
# k-Nearest Neighbors          9.86          10.14
# Bagging Regressor            2.62          13.65
# Random Forest                0.22           5.05
# Gradient Boosting            0.04           3.21
# ------ Results for airline: B6 -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      24.22  1623.34  19.11     40.29         0.05
# Ridge                  24.22  1623.34  19.11     40.29         0.03
# Lasso                  24.22  1623.33  19.11     40.29         0.08
# Elastic Net            24.22  1623.33  19.11     40.29         0.08
# Polynomial Features    23.20  1562.51  22.14     39.53         3.48
# k-Nearest Neighbors    23.35  1575.06  21.52     39.69         0.40
# Bagging Regressor      23.78  1574.05  21.57     39.67        17.93
# Random Forest          22.40  1487.30  25.89     38.57         8.05
# Gradient Boosting      23.16  1555.79  22.48     39.44         6.19
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.05
# Ridge                        0.00           0.03
# Lasso                        0.00           0.08
# Elastic Net                  0.00           0.09
# Polynomial Features          0.02           3.50
# k-Nearest Neighbors         14.42          14.82
# Bagging Regressor            6.04          23.96
# Random Forest                0.33           8.38
# Gradient Boosting            0.07           6.26
# ------ Results for airline: DL -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      18.51  1577.31  11.67     39.72         0.18
# Ridge                  18.51  1577.31  11.67     39.72         0.10
# Lasso                  18.51  1577.28  11.67     39.72         0.26
# Elastic Net            18.51  1577.28  11.67     39.72         0.26
# Polynomial Features    18.16  1556.23  12.85     39.45        11.21
# k-Nearest Neighbors    18.34  1566.92  12.25     39.58        27.30
# Bagging Regressor      18.68  1576.73  11.70     39.71       225.78
# Random Forest          17.31  1471.94  17.57     38.37        42.31
# Gradient Boosting      18.10  1550.16  13.19     39.37        32.14
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.18
# Ridge                        0.00           0.10
# Lasso                        0.00           0.26
# Elastic Net                  0.00           0.26
# Polynomial Features          0.06          11.27
# k-Nearest Neighbors         91.62         118.92
# Bagging Regressor           70.91         296.69
# Random Forest                1.59          43.90
# Gradient Boosting            0.48          32.62
# ------ Results for airline: EV -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      24.25  2549.36   4.75     50.49         0.35
# Ridge                  24.25  2549.35   4.75     50.49         0.05
# Lasso                  24.25  2549.29   4.76     50.49         0.16
# Elastic Net            24.25  2549.29   4.76     50.49         0.16
# Polynomial Features    23.89  2544.24   4.95     50.44         5.96
# k-Nearest Neighbors    24.12  2572.17   3.90     50.72         0.89
# Bagging Regressor      25.41  2684.45  -0.29     51.81        35.53
# Random Forest          23.32  2483.60   7.21     49.84        16.78
# Gradient Boosting      23.85  2533.16   5.36     50.33        14.06
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.35
# Ridge                        0.00           0.05
# Lasso                        0.02           0.18
# Elastic Net                  0.00           0.17
# Polynomial Features          0.03           5.99
# k-Nearest Neighbors         36.13          37.01
# Bagging Regressor           13.32          48.85
# Random Forest                0.58          17.35
# Gradient Boosting            0.11          14.17
# ------ Results for airline: F9 -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      26.49  2294.35  13.89     47.90         0.01
# Ridge                  26.49  2294.23  13.89     47.90         0.01
# Lasso                  26.49  2294.20  13.89     47.90         0.03
# Elastic Net            26.49  2294.20  13.89     47.90         0.03
# Polynomial Features    26.13  2292.95  13.94     47.88         1.12
# k-Nearest Neighbors    26.56  2333.18  12.43     48.30         0.09
# Bagging Regressor      28.02  2474.02   7.15     49.74         6.20
# Random Forest          25.80  2255.00  15.37     47.49         2.34
# Gradient Boosting      26.06  2273.72  14.66     47.68         1.15
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.02
# Ridge                        0.00           0.01
# Lasso                        0.00           0.03
# Elastic Net                  0.00           0.03
# Polynomial Features          0.01           1.13
# k-Nearest Neighbors          3.71           3.80
# Bagging Regressor            1.65           7.85
# Random Forest                0.11           2.45
# Gradient Boosting            0.02           1.17
# ------ Results for airline: HA -------
#                     MAE (mn)     MSE  R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression       9.74  637.40    1.98     25.25         0.01
# Ridge                   9.72  637.08    2.02     25.24         0.01
# Lasso                   9.70  636.94    2.05     25.24         0.02
# Elastic Net             9.70  636.94    2.05     25.24         0.02
# Polynomial Features    10.09  754.92  -16.10     27.48         0.97
# k-Nearest Neighbors     9.52  645.34    0.75     25.40         0.11
# Bagging Regressor      10.11  764.73  -17.61     27.65         5.00
# Random Forest           9.35  651.27   -0.16     25.52         1.82
# Gradient Boosting       9.59  699.54   -7.58     26.45         0.83
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.01
# Ridge                        0.00           0.01
# Lasso                        0.00           0.02
# Elastic Net                  0.00           0.02
# Polynomial Features          0.01           0.98
# k-Nearest Neighbors          2.19           2.30
# Bagging Regressor            1.56           6.56
# Random Forest                0.11           1.93
# Gradient Boosting            0.01           0.84
# ------ Results for airline: NK -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      24.48  1914.10   8.39     43.75         0.02
# Ridge                  24.47  1914.07   8.39     43.75         0.01
# Lasso                  24.47  1914.00   8.39     43.75         0.03
# Elastic Net            24.47  1914.00   8.39     43.75         0.03
# Polynomial Features    24.02  1898.75   9.12     43.57         1.63
# k-Nearest Neighbors    24.41  1933.27   7.47     43.97         0.15
# Bagging Regressor      25.90  2124.94  -1.70     46.10         8.64
# Random Forest          23.83  1889.50   9.57     43.47         3.46
# Gradient Boosting      24.00  1897.19   9.20     43.56         1.96
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.02
# Ridge                        0.00           0.01
# Lasso                        0.00           0.04
# Elastic Net                  0.00           0.04
# Polynomial Features          0.01           1.64
# k-Nearest Neighbors          6.77           6.92
# Bagging Regressor            1.90          10.54
# Random Forest                0.22           3.68
# Gradient Boosting            0.03           2.00
# ------ Results for airline: OO -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      21.69  2108.85   3.90     45.92         0.12
# Ridge                  21.69  2108.84   3.90     45.92         0.06
# Lasso                  21.69  2108.79   3.90     45.92         0.20
# Elastic Net            21.69  2108.79   3.90     45.92         0.20
# Polynomial Features    21.52  2102.94   4.17     45.86         7.38
# k-Nearest Neighbors    21.92  2130.07   2.93     46.15         1.63
# Bagging Regressor      22.91  2221.43  -1.23     47.13        45.47
# Random Forest          20.94  2041.33   6.98     45.18        23.82
# Gradient Boosting      21.46  2098.30   4.38     45.81        18.44
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.12
# Ridge                        0.00           0.06
# Lasso                        0.00           0.20
# Elastic Net                  0.00           0.20
# Polynomial Features          0.04           7.42
# k-Nearest Neighbors         55.77          57.40
# Bagging Regressor           15.00          60.47
# Random Forest                0.83          24.65
# Gradient Boosting            0.12          18.57
# ------ Results for airline: UA -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      23.30  1796.54   7.23     42.39         0.10
# Ridge                  23.30  1796.54   7.23     42.39         0.05
# Lasso                  23.30  1796.50   7.23     42.39         0.18
# Elastic Net            23.30  1796.50   7.23     42.39         0.18
# Polynomial Features    22.87  1776.19   8.28     42.14         6.84
# k-Nearest Neighbors    22.97  1768.45   8.68     42.05         0.90
# Bagging Regressor      23.61  1772.92   8.45     42.11        38.08
# Random Forest          22.05  1682.10  13.14     41.01        18.77
# Gradient Boosting      22.79  1766.03   8.81     42.02        16.42
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.10
# Ridge                        0.00           0.06
# Lasso                        0.00           0.18
# Elastic Net                  0.00           0.18
# Polynomial Features          0.04           6.88
# k-Nearest Neighbors         43.98          44.88
# Bagging Regressor           13.44          51.52
# Random Forest                0.70          19.47
# Gradient Boosting            0.13          16.55
# ------ Results for airline: VX -------
#                     MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      21.23  1136.26  19.46     33.71         0.01
# Ridge                  21.23  1136.22  19.46     33.71         0.01
# Lasso                  21.23  1136.24  19.46     33.71         0.02
# Elastic Net            21.22  1136.14  19.47     33.71         0.02
# Polynomial Features    20.16  1075.30  23.78     32.79         0.77
# k-Nearest Neighbors    19.90  1070.43  24.12     32.72         0.06
# Bagging Regressor      19.77  1045.00  25.93     32.33         4.10
# Random Forest          19.06   999.76  29.13     31.62         1.35
# Gradient Boosting      19.94  1054.51  25.25     32.47         0.77
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.00           0.01
# Ridge                        0.00           0.01
# Lasso                        0.00           0.02
# Elastic Net                  0.00           0.02
# Polynomial Features          0.01           0.77
# k-Nearest Neighbors          1.76           1.82
# Bagging Regressor            1.50           5.60
# Random Forest                0.11           1.45
# Gradient Boosting            0.02           0.79
# ------ Results for airline: WN -------
#                     MAE (mn)     MSE R2 (%) RMSE (mn) fit_time (s)  \
# Linear Regression      16.56  839.44  12.88     28.97         0.25
# Ridge                  16.56  839.44  12.88     28.97         0.13
# Lasso                  16.56  839.44  12.88     28.97         2.65
# Elastic Net            16.56  839.45  12.88     28.97         1.82
# Polynomial Features    16.08  813.21  15.60     28.52        15.90
# k-Nearest Neighbors    16.01  800.84  16.88     28.30         3.51
# Bagging Regressor      16.07  776.47  19.41     27.87       668.13
# Random Forest          15.25  749.65  22.20     27.38        51.94
# Gradient Boosting      16.05  812.14  15.71     28.50        48.95
#
#                     pred_time (s) total_time (s)
# Linear Regression            0.01           0.25
# Ridge                        0.01           0.14
# Lasso                        0.01           2.65
# Elastic Net                  0.01           1.83
# Polynomial Features          0.09          15.99
# k-Nearest Neighbors         62.13          65.64
# Bagging Regressor          226.34         894.47
# Random Forest                2.62          54.56
# Gradient Boosting            0.35          49.30

# %% [markdown]
# ## Results by method

# %%
for i, method in enumerate(models.keys()):
    print(f"----- Results with method: {method} -----") 
    display(pd.DataFrame([v[i] for v in results.values()], index=results.keys()))
    print("\n")
# Out:
# ----- Results with method: Linear Regression -----
#    MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    21.85  1970.28   5.95     44.39         0.17          0.00
# AS    14.78   686.01   6.67     26.19         0.11          0.00
# B6    24.22  1623.34  19.11     40.29         0.05          0.00
# DL    18.51  1577.31  11.67     39.72         0.18          0.00
# EV    24.25  2549.36   4.75     50.49         0.35          0.00
# F9    26.49  2294.35  13.89     47.90         0.01          0.00
# HA     9.74   637.40   1.98     25.25         0.01          0.00
# NK    24.48  1914.10   8.39     43.75         0.02          0.00
# OO    21.69  2108.85   3.90     45.92         0.12          0.00
# UA    23.30  1796.54   7.23     42.39         0.10          0.00
# VX    21.23  1136.26  19.46     33.71         0.01          0.00
# WN    16.56   839.44  12.88     28.97         0.25          0.01
#
#    total_time (s)
# AA           0.18
# AS           0.11
# B6           0.05
# DL           0.18
# EV           0.35
# F9           0.02
# HA           0.01
# NK           0.02
# OO           0.12
# UA           0.10
# VX           0.01
# WN           0.25
# ----- Results with method: Ridge -----
#    MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    21.85  1970.28   5.95     44.39         0.09          0.00
# AS    14.78   685.91   6.69     26.19         0.02          0.00
# B6    24.22  1623.34  19.11     40.29         0.03          0.00
# DL    18.51  1577.31  11.67     39.72         0.10          0.00
# EV    24.25  2549.35   4.75     50.49         0.05          0.00
# F9    26.49  2294.23  13.89     47.90         0.01          0.00
# HA     9.72   637.08   2.02     25.24         0.01          0.00
# NK    24.47  1914.07   8.39     43.75         0.01          0.00
# OO    21.69  2108.84   3.90     45.92         0.06          0.00
# UA    23.30  1796.54   7.23     42.39         0.05          0.00
# VX    21.23  1136.22  19.46     33.71         0.01          0.00
# WN    16.56   839.44  12.88     28.97         0.13          0.01
#
#    total_time (s)
# AA           0.10
# AS           0.02
# B6           0.03
# DL           0.10
# EV           0.05
# F9           0.01
# HA           0.01
# NK           0.01
# OO           0.06
# UA           0.06
# VX           0.01
# WN           0.14
# ----- Results with method: Lasso -----
#    MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    21.85  1970.27   5.95     44.39         0.36          0.00
# AS    14.78   685.96   6.68     26.19         0.04          0.00
# B6    24.22  1623.33  19.11     40.29         0.08          0.00
# DL    18.51  1577.28  11.67     39.72         0.26          0.00
# EV    24.25  2549.29   4.76     50.49         0.16          0.02
# F9    26.49  2294.20  13.89     47.90         0.03          0.00
# HA     9.70   636.94   2.05     25.24         0.02          0.00
# NK    24.47  1914.00   8.39     43.75         0.03          0.00
# OO    21.69  2108.79   3.90     45.92         0.20          0.00
# UA    23.30  1796.50   7.23     42.39         0.18          0.00
# VX    21.23  1136.24  19.46     33.71         0.02          0.00
# WN    16.56   839.44  12.88     28.97         2.65          0.01
#
#    total_time (s)
# AA           0.37
# AS           0.05
# B6           0.08
# DL           0.26
# EV           0.18
# F9           0.03
# HA           0.02
# NK           0.04
# OO           0.20
# UA           0.18
# VX           0.02
# WN           2.65
# ----- Results with method: Elastic Net -----
#    MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    21.85  1970.27   5.95     44.39         0.36          0.00
# AS    14.78   685.96   6.68     26.19         0.04          0.00
# B6    24.22  1623.33  19.11     40.29         0.08          0.00
# DL    18.51  1577.28  11.67     39.72         0.26          0.00
# EV    24.25  2549.29   4.76     50.49         0.16          0.00
# F9    26.49  2294.20  13.89     47.90         0.03          0.00
# HA     9.70   636.94   2.05     25.24         0.02          0.00
# NK    24.47  1914.00   8.39     43.75         0.03          0.00
# OO    21.69  2108.79   3.90     45.92         0.20          0.00
# UA    23.30  1796.50   7.23     42.39         0.18          0.00
# VX    21.22  1136.14  19.47     33.71         0.02          0.00
# WN    16.56   839.45  12.88     28.97         1.82          0.01
#
#    total_time (s)
# AA           0.37
# AS           0.05
# B6           0.09
# DL           0.26
# EV           0.17
# F9           0.03
# HA           0.02
# NK           0.04
# OO           0.20
# UA           0.18
# VX           0.02
# WN           1.83
# ----- Results with method: Polynomial Features -----
#    MAE (mn)      MSE  R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    21.48  1952.00    6.82     44.18        12.12          0.06
# AS    14.71   682.04    7.21     26.12         2.20          0.01
# B6    23.20  1562.51   22.14     39.53         3.48          0.02
# DL    18.16  1556.23   12.85     39.45        11.21          0.06
# EV    23.89  2544.24    4.95     50.44         5.96          0.03
# F9    26.13  2292.95   13.94     47.88         1.12          0.01
# HA    10.09   754.92  -16.10     27.48         0.97          0.01
# NK    24.02  1898.75    9.12     43.57         1.63          0.01
# OO    21.52  2102.94    4.17     45.86         7.38          0.04
# UA    22.87  1776.19    8.28     42.14         6.84          0.04
# VX    20.16  1075.30   23.78     32.79         0.77          0.01
# WN    16.08   813.21   15.60     28.52        15.90          0.09
#
#    total_time (s)
# AA          12.19
# AS           2.21
# B6           3.50
# DL          11.27
# EV           5.99
# F9           1.13
# HA           0.98
# NK           1.64
# OO           7.42
# UA           6.88
# VX           0.77
# WN          15.99
# ----- Results with method: k-Nearest Neighbors -----
#    MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    21.71  1965.43   6.18     44.33         2.56         71.67
# AS    14.82   688.56   6.32     26.24         0.28          9.86
# B6    23.35  1575.06  21.52     39.69         0.40         14.42
# DL    18.34  1566.92  12.25     39.58        27.30         91.62
# EV    24.12  2572.17   3.90     50.72         0.89         36.13
# F9    26.56  2333.18  12.43     48.30         0.09          3.71
# HA     9.52   645.34   0.75     25.40         0.11          2.19
# NK    24.41  1933.27   7.47     43.97         0.15          6.77
# OO    21.92  2130.07   2.93     46.15         1.63         55.77
# UA    22.97  1768.45   8.68     42.05         0.90         43.98
# VX    19.90  1070.43  24.12     32.72         0.06          1.76
# WN    16.01   800.84  16.88     28.30         3.51         62.13
#
#    total_time (s)
# AA          74.23
# AS          10.14
# B6          14.82
# DL         118.92
# EV          37.01
# F9           3.80
# HA           2.30
# NK           6.92
# OO          57.40
# UA          44.88
# VX           1.82
# WN          65.64
# ----- Results with method: Bagging Regressor -----
#    MAE (mn)      MSE  R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    22.39  2008.27    4.13     44.81       184.55        121.58
# AS    15.16   713.96    2.87     26.72        11.03          2.62
# B6    23.78  1574.05   21.57     39.67        17.93          6.04
# DL    18.68  1576.73   11.70     39.71       225.78         70.91
# EV    25.41  2684.45   -0.29     51.81        35.53         13.32
# F9    28.02  2474.02    7.15     49.74         6.20          1.65
# HA    10.11   764.73  -17.61     27.65         5.00          1.56
# NK    25.90  2124.94   -1.70     46.10         8.64          1.90
# OO    22.91  2221.43   -1.23     47.13        45.47         15.00
# UA    23.61  1772.92    8.45     42.11        38.08         13.44
# VX    19.77  1045.00   25.93     32.33         4.10          1.50
# WN    16.07   776.47   19.41     27.87       668.13        226.34
#
#    total_time (s)
# AA         306.13
# AS          13.65
# B6          23.96
# DL         296.69
# EV          48.85
# F9           7.85
# HA           6.56
# NK          10.54
# OO          60.47
# UA          51.52
# VX           5.60
# WN         894.47
# ----- Results with method: Random Forest -----
#    MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    20.78  1873.72  10.55     43.29        37.58          1.56
# AS    14.24   659.17  10.32     25.67         4.83          0.22
# B6    22.40  1487.30  25.89     38.57         8.05          0.33
# DL    17.31  1471.94  17.57     38.37        42.31          1.59
# EV    23.32  2483.60   7.21     49.84        16.78          0.58
# F9    25.80  2255.00  15.37     47.49         2.34          0.11
# HA     9.35   651.27  -0.16     25.52         1.82          0.11
# NK    23.83  1889.50   9.57     43.47         3.46          0.22
# OO    20.94  2041.33   6.98     45.18        23.82          0.83
# UA    22.05  1682.10  13.14     41.01        18.77          0.70
# VX    19.06   999.76  29.13     31.62         1.35          0.11
# WN    15.25   749.65  22.20     27.38        51.94          2.62
#
#    total_time (s)
# AA          39.14
# AS           5.05
# B6           8.38
# DL          43.90
# EV          17.35
# F9           2.45
# HA           1.93
# NK           3.68
# OO          24.65
# UA          19.47
# VX           1.45
# WN          54.56
# ----- Results with method: Gradient Boosting -----
#    MAE (mn)      MSE R2 (%) RMSE (mn) fit_time (s) pred_time (s)  \
# AA    21.45  1947.99   7.01     44.14        32.15          0.23
# AS    14.64   679.07   7.62     26.06         3.18          0.04
# B6    23.16  1555.79  22.48     39.44         6.19          0.07
# DL    18.10  1550.16  13.19     39.37        32.14          0.48
# EV    23.85  2533.16   5.36     50.33        14.06          0.11
# F9    26.06  2273.72  14.66     47.68         1.15          0.02
# HA     9.59   699.54  -7.58     26.45         0.83          0.01
# NK    24.00  1897.19   9.20     43.56         1.96          0.03
# OO    21.46  2098.30   4.38     45.81        18.44          0.12
# UA    22.79  1766.03   8.81     42.02        16.42          0.13
# VX    19.94  1054.51  25.25     32.47         0.77          0.02
# WN    16.05   812.14  15.71     28.50        48.95          0.35
#
#    total_time (s)
# AA          32.38
# AS           3.21
# B6           6.26
# DL          32.62
# EV          14.17
# F9           1.17
# HA           0.84
# NK           2.00
# OO          18.57
# UA          16.55
# VX           0.79
# WN          49.30

# %% [markdown]
# ## Results consolidated

# %%
airlines = ['AA', 'AS', 'B6', 'DL', 'EV', 'F9', 'HA',
            'NK', 'OO', 'UA', 'VX', 'WN']

y_test_size = sum([infos[x]['y_test_size'] for x in airlines])
y_test_sum = sum([infos[x]['y_test_sum'] for x in airlines])
y_test_mean = y_test_sum / y_test_size
y_test_sum_squared = sum([infos[x]['y_test_sum_squared'] for x in airlines])

r2_denum = y_test_sum_squared - 2*y_test_mean*y_test_sum + y_test_size * y_test_mean ** 2

global_results = []
for i, method in enumerate(models.keys()):
    r2_num = sum([infos[x]['y_test_size'] * float(results[x][i]['MSE']) for x in airlines])
    global_results.append({
        'MSE': f"{sum([infos[x]['y_test_size'] * float(results[x][i]['MSE']) for x in airlines]) / y_test_size:.2f}",
        'RMSE (mn)': f"{(sum([infos[x]['y_test_size'] * float(results[x][i]['MSE']) for x in airlines]) / y_test_size) ** 0.5:.2f}",
        'MAE (mn)': f"{sum([infos[x]['y_test_size'] * float(results[x][i]['MAE (mn)']) for x in airlines]) / y_test_size:.2f}",
        'R2 (%)': f"{100*(1 - (r2_num / r2_denum)):.2f}",
        'fit_time (s)': sum([float(results[x][i]['fit_time (s)']) for x in airlines]),
        'pred_time (s)': sum([float(results[x][i]['pred_time (s)']) for x in airlines]),
        'total_time (s)': sum([float(results[x][i]['total_time (s)']) for x in airlines]),
    })
    
display(pd.DataFrame(global_results, index=models.keys()))
# Out:
#                     MAE (mn)      MSE R2 (%) RMSE (mn)  fit_time (s)  \
# Linear Regression      20.27  1608.87   9.04     40.11          1.38
# Ridge                  20.27  1608.86   9.04     40.11          0.57
# Lasso                  20.27  1608.83   9.04     40.11          4.03
# Elastic Net            20.27  1608.83   9.04     40.11          3.20
# Polynomial Features    19.87  1590.58  10.07     39.88         69.58
# k-Nearest Neighbors    20.01  1597.04   9.71     39.96         37.88
# Bagging Regressor      20.57  1629.10   7.89     40.36       1250.44
# Random Forest          19.14  1520.45  14.04     38.99        213.05
# Gradient Boosting      19.81  1584.42  10.42     39.80        176.24
#
#                      pred_time (s)  total_time (s)
# Linear Regression             0.01            1.40
# Ridge                         0.01            0.60
# Lasso                         0.03            4.08
# Elastic Net                   0.01            3.26
# Polynomial Features           0.39           69.97
# k-Nearest Neighbors         400.01          437.88
# Bagging Regressor           475.86         1726.29
# Random Forest                 8.98          222.01
# Gradient Boosting             1.61          177.86

# %% [markdown]
# Le modèle choisi est la régression linéaire avec features polynomiales (degré 3). C'est le meilleur compromis résultat/vitesse pour être implémenté dans l'API.

# %% [markdown]
# ## Final model - Export parameters

# %%
airlines = ['AA', 'AS', 'B6', 'DL', 'EV', 'F9', 
            'HA', 'NK', 'OO', 'UA', 'VX', 'WN']

reg_params = {}
encoding_tables = defaultdict(dict)

for airline in airlines:
    print(f"---------- Start Airline : {airline} ---------------")
    start = timer()
    X = pd.read_csv(f'C:/Users/Serphone/Data/OCR_DS_P4/AIRLINE_DATASETS/{airline}.csv')
    y = X.pop('ARR_DELAY')
    
    encoding_tables[f'{airline}']['default'] = y.mean()
    # Encode
    for col in ['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 'ORIGIN_AIRPORT_ID', 
                'DEST_AIRPORT_ID', 'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME']:
        means = pd.concat([X, y], axis=1).groupby(by=f'{col}').ARR_DELAY.mean()
        encoding_tables[f'{airline}'][f'{col}'] = dict(means) 
        X[f'{col}'] = X[f'{col}'].map(means)
    
    # Standardize
    scaler = StandardScaler().fit(X)
    X_std = scaler.transform(X)
    
    # Make polynomial features
    poly = PolynomialFeatures(degree=3)
    X_poly = poly.fit_transform(X_std)
    
    # Fit linear regression model
    reg = LinearRegression(n_jobs=-1).fit(X_poly, y)
    
    # Save parameters
    reg_params[airline] = {
        'scale_': scaler.scale_,
        'mean_': scaler.mean_,
        'var_': scaler.var_,
        'coef_': reg.coef_,
        'intercept_': reg.intercept_
    }
          
    end = timer()
    print(f"---------- End Airline : {airline} - {end-start:.2f}s ---------------")
    
with open ('reg_params.pickle', 'wb') as f:
    pickle.dump(reg_params, f)

with open('encoding_params.pickle', 'wb') as f:
    pickle.dump(encoding_tables, f)
# Out:
# ---------- Start Airline : AA ---------------
# ---------- End Airline : AA - 27.55s ---------------
# ---------- Start Airline : AS ---------------
# ---------- End Airline : AS - 4.52s ---------------
# ---------- Start Airline : B6 ---------------
# ---------- End Airline : B6 - 7.22s ---------------
# ---------- Start Airline : DL ---------------
# ---------- End Airline : DL - 23.77s ---------------
# ---------- Start Airline : EV ---------------
# ---------- End Airline : EV - 13.05s ---------------
# ---------- Start Airline : F9 ---------------
# ---------- End Airline : F9 - 2.49s ---------------
# ---------- Start Airline : HA ---------------
# ---------- End Airline : HA - 1.94s ---------------
# ---------- Start Airline : NK ---------------
# ---------- End Airline : NK - 3.58s ---------------
# ---------- Start Airline : OO ---------------
# ---------- End Airline : OO - 15.22s ---------------
# ---------- Start Airline : UA ---------------
# ---------- End Airline : UA - 13.70s ---------------
# ---------- Start Airline : VX ---------------
# ---------- End Airline : VX - 1.67s ---------------
# ---------- Start Airline : WN ---------------
# ---------- End Airline : WN - 90.75s ---------------
